# %% [markdown]
# # Clickbait Challenge at SemEval 2023 - Clickbait Spoiling
#
# https://pan.webis.de/semeval23/pan23-web/clickbait-challenge.html
#
# Clickbait posts link to web pages and advertise their content by arousing curiosity instead of providing informative summaries. Clickbait spoiling aims at generating short texts that satisfy the curiosity induced by a clickbait post.

# %% [markdown]
# ##Tasks
# ###Task 1: Spoiler Type Classification
# The input is the clickbait post and the linked document. The task is to classify the spoiler type that the clickbait post warrants (either "phrase", "passage", "multi"). For each input, an output like `{"uuid": "<UUID>", "spoilerType": "<SPOILER-TYPE>"}` has to be generated where `<SPOILER-TYPE>` is either `phrase`, `passage`, or `multi`.
#
# ###Task 2: Spoiler Generation
# The input is the clickbait post and the linked document (and, optional, the spoiler type if your approach uses this field). The task is to generate the spoiler for the clickbait post. For each input, an output like `{"uuid": "<UUID>", "spoiler": "<SPOILER>"}` has to be generated where `<SPOILER>` is the spoiler for the clickbait post.

# %% [markdown]
# For each entry in the training and validation dataset, the following fields are available (https://aclanthology.org/2022.acl-long.484.pdf):
#
# * ``uuid``: The uuid of the dataset entry.
# * ``postText``: The text of the clickbait post which is to be spoiled.
# * ``targetParagraphs``: The main content of the linked web page to classify the spoiler type (task 1) and to generate the spoiler (task 2). Consists of the paragraphs of manually extracted main content.
# * ``targetTitle``: The title of the linked web page to classify the spoiler type (task 1) and to generate the spoiler (task 2).
# * ``targetUrl``: The URL of the linked web page.
# * ``humanSpoiler``: The human generated spoiler (abstractive) for the clickbait post from the linked web page. This field is only available in the training and validation dataset (not during test).
# * ``spoiler``: The human extracted spoiler for the clickbait post from the linked web page. This field is only available in the training and validation dataset (not during test).
# * ``spoilerPositions``: The position of the human extracted spoiler for the clickbait post from the linked web page. This field is only available in the training and validation dataset (not during test).
# * ``tags``: The spoiler type (might be "phrase", "passage", or "multi") that is to be classified in task 1 (spoiler type classification). For task 1, this field is only available in the training and validation dataset (not during test). For task 2, this field is always available and can be used.
# * Some fields contain additional metainformation about the entry but are unused: postId, postPlatform, targetDescription, targetKeywords, targetMedia.

# %% [markdown]
# ## First steps

# %% [markdown]
# ### Installations

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 25.0 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 53.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.28.1

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 10.6 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 16.2 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.13.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.27.1)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (23.1.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 14.9 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 13.4 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 22.0 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.11.0 dill-0.3.6 frozenlist-1.3.3 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0 yarl-1.8.2

# %%
# !pip install evaluate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/dist-packages (from evaluate) (3.2.0)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from evaluate) (2.11.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.9/dist-packages (from evaluate) (0.3.6)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.9/dist-packages (from evaluate) (0.18.0)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.9/dist-packages (from evaluate) (2023.4.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from evaluate) (0.13.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from evaluate) (4.65.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from evaluate) (23.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from evaluate) (1.22.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from evaluate) (2.27.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from evaluate) (1.5.3)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.9/dist-packages (from evaluate) (0.70.14)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->evaluate) (9.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->evaluate) (3.8.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.7.0->evaluate) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->evaluate) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->evaluate) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->evaluate) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->evaluate) (2022.7.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.0

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.9/dist-packages (3.5.2)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (4.65.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.1.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.10.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (23.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.22.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.4.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy) (67.6.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.27.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.15)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy) (2.1.2)
# 2023-04-21 11:17:00.726863: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-21 11:17:02.546504: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-04-21 11:17:04.664130: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-21 11:17:04.664758: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-21 11:17:04.665028: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 37.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.9/dist-packages (from en-core-web-sm==3.5.0) (3.5.2)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.27.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.9)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (67.6.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.22.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.65.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.15)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import json
import random
import numpy as np
import os
import evaluate
import spacy

from datasets import DatasetDict, Dataset, ClassLabel, Features
from datasets import load_dataset, load_metric
from datasets import Dataset, Value

import transformers
from transformers import AutoTokenizer
from transformers import DataCollatorWithPadding
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support

import torch
import tensorflow as tf

# %% [markdown]
# ### Google Drive and GPU

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %% [markdown]
# ### Initializations
# To choose the general parameters for our model.

# %%
# Name of the model chosen
model_checkpoint = "distilbert-base-uncased"

# True if Spacy is applied. False, Spacy is not applied.
spacy_check = True

# True if [CLS] and [SEP] are added mannually. False, the columns are concatenated without special tokens.
tokens_check = False

# True so add_special_tokens = False. False, special tokens are added.
tokenizer_check = False

# %% [markdown]
# ## Creating the right data

# %% [markdown]
# ### Load in Pandas Dataframe

# %%
# Load the train data
train_data = pd.read_json('/content/drive/My Drive/Colab Notebooks/2023-ILTAPP/APP1_Assignment/data/train.jsonl', lines=True)
train_data = train_data.drop(columns=['postId', 'postPlatform', 'targetDescription', 'targetKeywords', 'targetMedia', 'targetUrl', 'provenance', 'spoiler', 'spoilerPositions'])

# Load the validation data
val_data = pd.read_json('/content/drive/My Drive/Colab Notebooks/2023-ILTAPP/APP1_Assignment/data/validation.jsonl', lines=True)
val_data = val_data.drop(columns=['postId', 'postPlatform', 'targetDescription', 'targetKeywords', 'targetMedia', 'targetUrl', 'provenance', 'spoiler', 'spoilerPositions'])

# %%
train_data.head()
# Out:
#                                    uuid  \
# 0  0af11f6b-c889-4520-9372-66ba25cb7657
# 1  b1a1f63d-8853-4a11-89e8-6b2952a393ec
# 2  008b7b19-0445-4e16-8f9e-075b73f80ca4
# 3  31ecf93c-3e21-4c80-949b-aa549a046b93
# 4  31b108a3-c828-421a-a4b9-cf651e9ac859
#
#                                             postText  \
# 0  [Wes Welker Wanted Dinner With Tom Brady, But ...
# 1   [NASA sets date for full recovery of ozone hole]
# 2  [This is what makes employees happy -- and it'...
# 3  [Passion is overrated — 7 work habits you need...
# 4  [The perfect way to cook rice so that it's per...
#
#                                     targetParagraphs  \
# 0  [It’ll be just like old times this weekend for...
# 1  [2070 is shaping up to be a great year for Mot...
# 2  [Despite common belief, money isn't the key to...
# 3  [It’s common wisdom. Near gospel really, and n...
# 4  [Boiling rice may seem simple, but there is a ...
#
#                                          targetTitle       tags
# 0  Wes Welker Wanted Dinner With Tom Brady, But P...  [passage]
# 1  Hole In Ozone Layer Expected To Make Full Reco...   [phrase]
# 2  Intellectual Stimulation Trumps Money For Empl...   [phrase]
# 3  ‘Follow your passion’ is wrong, here are 7 hab...    [multi]
# 4  Revealed: The perfect way to cook rice so that...   [phrase]

# %% [markdown]
# ### Convert to strings

# %%
# To strings (run just once)
train_data['tags'] = train_data['tags'].apply(lambda x: ','.join(x))
print(type(train_data.loc[0, 'tags']))
train_data['postText'] = train_data['postText'].apply(lambda x: ','.join(x))
print(type(train_data.loc[0, 'postText']))
train_data['targetParagraphs'] = train_data['targetParagraphs'].apply(lambda x: ','.join(x))
print(type(train_data.loc[0, 'targetParagraphs']))
print(type(train_data.loc[0, 'targetTitle']))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
# To strings (run just once)
val_data['tags'] = val_data['tags'].apply(lambda x: ','.join(x))
print(type(val_data.loc[0, 'tags']))
val_data['postText'] = val_data['postText'].apply(lambda x: ','.join(x))
print(type(val_data.loc[0, 'postText']))
val_data['targetParagraphs'] = val_data['targetParagraphs'].apply(lambda x: ','.join(x))
print(type(val_data.loc[0, 'targetParagraphs']))
print(type(val_data.loc[0, 'targetTitle']))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
train_data.head()
# Out:
#                                    uuid  \
# 0  0af11f6b-c889-4520-9372-66ba25cb7657
# 1  b1a1f63d-8853-4a11-89e8-6b2952a393ec
# 2  008b7b19-0445-4e16-8f9e-075b73f80ca4
# 3  31ecf93c-3e21-4c80-949b-aa549a046b93
# 4  31b108a3-c828-421a-a4b9-cf651e9ac859
#
#                                             postText  \
# 0  Wes Welker Wanted Dinner With Tom Brady, But P...
# 1     NASA sets date for full recovery of ozone hole
# 2  This is what makes employees happy -- and it's...
# 3  Passion is overrated — 7 work habits you need ...
# 4  The perfect way to cook rice so that it's perf...
#
#                                     targetParagraphs  \
# 0  It’ll be just like old times this weekend for ...
# 1  2070 is shaping up to be a great year for Moth...
# 2  Despite common belief, money isn't the key to ...
# 3  It’s common wisdom. Near gospel really, and no...
# 4  Boiling rice may seem simple, but there is a v...
#
#                                          targetTitle     tags
# 0  Wes Welker Wanted Dinner With Tom Brady, But P...  passage
# 1  Hole In Ozone Layer Expected To Make Full Reco...   phrase
# 2  Intellectual Stimulation Trumps Money For Empl...   phrase
# 3  ‘Follow your passion’ is wrong, here are 7 hab...    multi
# 4  Revealed: The perfect way to cook rice so that...   phrase

# %% [markdown]
# ### Cleaning the texts

# %%
# Load Spacy
nlp = spacy.load("en_core_web_sm")

# Set the function to lowercase, remove punctuation and stopwords, and lemmatize.
def clean_text(text):
    doc = nlp(text)
    clean_tokens = [token.lemma_.lower().strip() for token in doc if not token.is_stop and not token.is_punct and token.is_alpha]
    return " ".join(clean_tokens)

# %%
if spacy_check == True:
  train_data['targetParagraphs'] = train_data['targetParagraphs'].apply(clean_text)
  val_data['targetParagraphs'] = val_data['targetParagraphs'].apply(clean_text)

# %% [markdown]
# ### Concatenate the fields

# %%
if tokens_check == True:
  train_data['text'] = '[CLS]' + ' ' + train_data['postText'] + ' ' + '[SEP]' + ' ' + train_data['targetParagraphs'] + ' ' + '[SEP]' + ' ' + train_data['targetTitle']
  val_data['text'] = '[CLS]' + ' ' + val_data['postText'] + ' ' + '[SEP]' + ' ' + val_data['targetParagraphs'] + ' ' + '[SEP]' + ' ' + val_data['targetTitle']
else:
  train_data['text'] = train_data['postText'] + ' ' + train_data['targetParagraphs'] + ' ' + train_data['targetTitle']
  val_data['text'] = val_data['postText'] + ' ' + val_data['targetParagraphs'] + ' ' + val_data['targetTitle']

# %%
train_data.head()
# val_data.head()
# Out:
#                                    uuid  \
# 0  0af11f6b-c889-4520-9372-66ba25cb7657
# 1  b1a1f63d-8853-4a11-89e8-6b2952a393ec
# 2  008b7b19-0445-4e16-8f9e-075b73f80ca4
# 3  31ecf93c-3e21-4c80-949b-aa549a046b93
# 4  31b108a3-c828-421a-a4b9-cf651e9ac859
#
#                                             postText  \
# 0  Wes Welker Wanted Dinner With Tom Brady, But P...
# 1     NASA sets date for full recovery of ozone hole
# 2  This is what makes employees happy -- and it's...
# 3  Passion is overrated — 7 work habits you need ...
# 4  The perfect way to cook rice so that it's perf...
#
#                                     targetParagraphs  \
# 0  like old time weekend tom brady wes welker rev...
# 1  shape great year mother earth nasa scientist p...
# 2  despite common belief money key employee happi...
# 3  common wisdom near gospel young people founder...
# 4  boiling rice simple fine line cook crunchy gra...
#
#                                          targetTitle     tags  \
# 0  Wes Welker Wanted Dinner With Tom Brady, But P...  passage
# 1  Hole In Ozone Layer Expected To Make Full Reco...   phrase
# 2  Intellectual Stimulation Trumps Money For Empl...   phrase
# 3  ‘Follow your passion’ is wrong, here are 7 hab...    multi
# 4  Revealed: The perfect way to cook rice so that...   phrase
#
#                                                 text
# 0  Wes Welker Wanted Dinner With Tom Brady, But P...
# 1  NASA sets date for full recovery of ozone hole...
# 2  This is what makes employees happy -- and it's...
# 3  Passion is overrated — 7 work habits you need ...
# 4  The perfect way to cook rice so that it's perf...

# %% [markdown]
# ### Create new dataframes with the columns we want

# %%
train_set = pd.DataFrame(train_data[['uuid', 'text', 'tags']])
# We change the name of 'tags' by 'labels' so that it can be understood by the transformer.
train_set = train_set.rename(columns={'tags': 'labels'})

val_set = pd.DataFrame(val_data[['uuid', 'text', 'tags']])
val_set = val_set.rename(columns={'tags': 'labels'})

val_set, test_set = train_test_split(val_set, test_size=0.2)

# train_set.info()
# train_set.head()
# val_set.info()
# val_set.head()
test_set.info()
test_set.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 160 entries, 21 to 693
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   uuid    160 non-null    object
#  1   text    160 non-null    object
#  2   labels  160 non-null    object
# dtypes: object(3)
# memory usage: 5.0+ KB
#                                      uuid  \
# 21   080bd61d-86f7-41f8-801e-3efc956b42aa
# 527  834a9942-a03b-4b60-ab11-12087683d844
# 105  32b0206a-4e69-4715-a630-82b324609f7c
# 440  890fd675-4629-410b-a574-759848b92dce
# 368  5cf96771-c43e-4589-aeb6-bbc33915f8ff
#
#                                                   text   labels
# 21   Is It Safe To Take Melatonin Pills To Help You...  passage
# 527  What The Heck Was This Smelly Pink Blob Floati...   phrase
# 105  Just a slight flaw with this argument... presi...  passage
# 440  Blocking this color light may help you sleep b...   phrase
# 368  Well this is awkward (PHOTOS) conventional wis...  passage

# %% [markdown]
# ### Save as jsonl files to load as datasets type

# %%
data_path = '/content/drive/My Drive/Colab Notebooks/2023-ILTAPP/APP1_Assignment/data/'

# save the json data to a file
with open(data_path + 'train_new.jsonl', 'w') as f:
  for index, row in train_set.iterrows():
    json.dump(row.to_dict(), f)
    f.write('\n')

with open(data_path + 'val_new.jsonl', 'w') as f:
  for index, row in val_set.iterrows():
    json.dump(row.to_dict(), f)
    f.write('\n')

with open(data_path + 'test_new.jsonl', 'w') as f:
  for index, row in test_set.iterrows():
    json.dump(row.to_dict(), f)
    f.write('\n')

# %% [markdown]
# ## Preprocessing the data

# %%
datasets = load_dataset('json', data_files = {
    "train": data_path + 'train_new.jsonl',
    "validation": data_path + 'val_new.jsonl',
    "test": data_path + 'test_new.jsonl'
})
# Out:
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-db29048cde64e73a/0.0.0/fe5dd6ea2639a6df622901539cb550cf8797e5a6b2dd7af1cf934bed8e233e6e...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-db29048cde64e73a/0.0.0/fe5dd6ea2639a6df622901539cb550cf8797e5a6b2dd7af1cf934bed8e233e6e. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['uuid', 'text', 'labels'],
#         num_rows: 3200
#     })
#     validation: Dataset({
#         features: ['uuid', 'text', 'labels'],
#         num_rows: 640
#     })
#     test: Dataset({
#         features: ['uuid', 'text', 'labels'],
#         num_rows: 160
#     })
# })

# %%
datasets["test"][0]
# Out:
# {'uuid': '563a7892-96ce-4237-ba75-69dec9d496a7',
#  'text': '@iamdiddy lost HOW MUCH to Rick Ross playing Craps?! million dollar pal rick ross play game dice yesterday specifically craps make bad diddy end owe ross million dollar rap mogul snap video event instagram caption lose million dollar be nothin suckmydickbitch turn post diddy iou note instagram write puff write contract win rollin dice dreamteam boutdatlife vegas family subsequently post photo caption vegas come meet club rain palm cirocboyz Diddy Loses A Million Dollars To Rick Ross In A Game Of Craps, Treats It Like Chump Change',
#  'labels': 'phrase'}

# %%
# We convert the labels to ClassLabels (integers)
label_map = ClassLabel(names=['multi', 'passage', 'phrase'])
datasets = datasets.map(lambda example: {'uuid': example['uuid'], 
                                         'text': example['text'], 
                                         'labels': label_map.str2int(example['labels'])})
# Out:
# Map:   0%|          | 0/3200 [00:00<?, ? examples/s]
# Map:   0%|          | 0/640 [00:00<?, ? examples/s]
# Map:   0%|          | 0/160 [00:00<?, ? examples/s]

# %% [markdown]
# ### Tokenizing

# %%
if tokenizer_check == True:
  tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, add_special_tokens=False)
else:
  tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# %%
def preprocess_function(batch):
    return tokenizer(batch["text"], padding=True, truncation=True)

# %%
tokenized_datasets = datasets.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/3200 [00:00<?, ? examples/s]
# Map:   0%|          | 0/640 [00:00<?, ? examples/s]
# Map:   0%|          | 0/160 [00:00<?, ? examples/s]

# %% [markdown]
# ## Fine-tunning the model

# %% [markdown]
# ### Model

# %%
# Create a dictionary with the ids and the relevant label.
label_list = ['multi', 'passage', 'phrase']
id2label = {i: label for i, label in enumerate(label_list)}
label2id = {v: k for k, v in id2label.items()}

# Download the model.
model = AutoModelForSequenceClassification.from_pretrained(model_checkpoint, num_labels=len(label_list), id2label=id2label, label2id=label2id)

# Set the DataCollator
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias', 'pre_classifier.weight', 'pre_classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Training arguments

# %%
# We set configuration to save the models in the corresponding directory.
configuration = ""
if spacy_check:
  configuration = configuration + "Spacy_"
else:
  configuration = configuration + "False_"

if tokens_check:
  configuration = configuration + "Tokens_"
else:
   configuration = configuration + "False_"

if tokenizer_check:
  configuration = configuration + "Tokenizer_"
else:
   configuration = configuration + "False_"

configuration
# Out:
# 'Spacy_False_False_'

# %%
model_name = model_checkpoint.split("/")[-1]

training_args = TrainingArguments(
    output_dir= f"/content/drive/My Drive/Colab Notebooks/2023-ILTAPP/APP1_Assignment/models/" + configuration + model_name,
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=10,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    optim="adamw_torch",
    load_best_model_at_end=True,
)

# %% [markdown]
# ### Metrics

# %%
accuracy = evaluate.load("accuracy")

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return accuracy.compute(predictions=predictions, references=labels)

# %% [markdown]
# ### Trainer

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

# %%
trainer.train()
# Out:
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='2000' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2000/2000 28:28, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.892285</td>
#       <td>0.589063</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.755582</td>
#       <td>0.673438</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.840300</td>
#       <td>0.781053</td>
#       <td>0.668750</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.840300</td>
#       <td>0.867232</td>
#       <td>0.664062</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.397300</td>
#       <td>1.028234</td>
#       <td>0.673438</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.397300</td>
#       <td>1.166110</td>
#       <td>0.657813</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.397300</td>
#       <td>1.314376</td>
#       <td>0.668750</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.125300</td>
#       <td>1.479267</td>
#       <td>0.659375</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.125300</td>
#       <td>1.556238</td>
#       <td>0.665625</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.042700</td>
#       <td>1.593402</td>
#       <td>0.662500</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2000, training_loss=0.3514093017578125, metrics={'train_runtime': 1710.4165, 'train_samples_per_second': 18.709, 'train_steps_per_second': 1.169, 'total_flos': 4239032352768000.0, 'train_loss': 0.3514093017578125, 'epoch': 10.0})

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='40' max='40' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [40/40 00:11]
#     </div>
# {'eval_loss': 0.7555822134017944,
#  'eval_accuracy': 0.6734375,
#  'eval_runtime': 11.4217,
#  'eval_samples_per_second': 56.034,
#  'eval_steps_per_second': 3.502,
#  'epoch': 10.0}

# %% [markdown]
# ## Testing

# %%
tokenizer = AutoTokenizer.from_pretrained(
    f"/content/drive/My Drive/Colab Notebooks/2023-ILTAPP/APP1_Assignment/models/{configuration}{model_name}/checkpoint-2000")
model = AutoModelForSequenceClassification.from_pretrained(
    f"/content/drive/My Drive/Colab Notebooks/2023-ILTAPP/APP1_Assignment/models/{configuration}{model_name}/checkpoint-2000")

num_correct = 0
total_examples = 0
true_labels = []
predicted_labels = []

for example in datasets["test"]:
    inputs = tokenizer(example['text'], return_tensors="pt", truncation=True)
    with torch.no_grad():
        logits = model(**inputs).logits
    predicted_class_id = logits.argmax().item()
    predicted_label = model.config.id2label[predicted_class_id]
    predicted_labels.append(predicted_label)
    true_label = example['labels']
    if isinstance(true_label, int):
        true_label = model.config.id2label[true_label]
    true_labels.append(true_label)
    uuid = example['uuid']
    print(f"UUID: {uuid}", f"True label: {true_label}", f"Predicted label: {predicted_label}")
    if predicted_label == true_label:
        num_correct += 1
    total_examples += 1

# We compute the metrics
accuracy = num_correct / total_examples
precision, recall, f1_score, _ = precision_recall_fscore_support(true_labels, predicted_labels, average='macro')
print(f"Accuracy: {accuracy:.3f}")
print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
print(f"F1-score: {f1_score:.3f}")
# Out:
# UUID: 080bd61d-86f7-41f8-801e-3efc956b42aa True label: passage Predicted label: passage
# UUID: 834a9942-a03b-4b60-ab11-12087683d844 True label: phrase Predicted label: passage
# UUID: 32b0206a-4e69-4715-a630-82b324609f7c True label: passage Predicted label: passage
# UUID: 890fd675-4629-410b-a574-759848b92dce True label: phrase Predicted label: phrase
# UUID: 5cf96771-c43e-4589-aeb6-bbc33915f8ff True label: passage Predicted label: passage
# UUID: 26c0a5c0-9348-4dd0-9136-9103fd78402a True label: passage Predicted label: multi
# UUID: 3f3fe676-0cd0-43f2-9cb5-ec77f7463cd3 True label: passage Predicted label: passage
# UUID: 6176bc74-00ba-43e6-860b-234127227d2a True label: phrase Predicted label: phrase
# UUID: 9b641d40-8b86-4906-b4c4-be8777f490fd True label: phrase Predicted label: phrase
# UUID: ab7c24f3-f96f-4a7a-86b0-2bf3ef63da59 True label: passage Predicted label: passage
# UUID: dfd4f870-0370-4889-9e30-979c86a7aeee True label: passage Predicted label: passage
# UUID: fe427180-ad89-4e2c-9720-409753aa28f4 True label: phrase Predicted label: phrase
# UUID: cb06d067-80d1-4c52-8cbb-0568729b3b21 True label: passage Predicted label: passage
# UUID: 052351c7-b04c-4557-bb62-1bba6fea57d4 True label: passage Predicted label: passage
# UUID: 00807e0e-d8e9-429b-aa54-160409acb574 True label: passage Predicted label: passage
# UUID: f8ecbcac-fd2a-4d12-8ebe-ea9c03118c74 True label: phrase Predicted label: multi
# UUID: e547d310-0a92-4b99-84b9-ae967c6c3ee6 True label: multi Predicted label: multi
# UUID: 2fa7e33c-5e68-4153-bf75-f226d9abe08f True label: passage Predicted label: passage
# UUID: cf1773fe-9ca2-4d29-bc02-c81ada90552a True label: passage Predicted label: passage
# UUID: 87266468-6149-4f74-9131-b33fdbab31cf True label: passage Predicted label: passage
# UUID: 6d5404db-6391-4f4f-8f45-85f7e111e860 True label: phrase Predicted label: phrase
# UUID: 0a5b3d8b-af6e-4e13-be29-e8d5883728bc True label: phrase Predicted label: phrase
# UUID: 517a65ee-4321-41dc-87a7-817e657e32b9 True label: multi Predicted label: phrase
# UUID: ec1827d5-7798-437e-bea1-0fd8f5c7eb7c True label: passage Predicted label: passage
# UUID: e042f5b2-bd6b-4c82-852b-2c7e9b59eb76 True label: passage Predicted label: passage
# UUID: 9e489af2-67a8-4c5d-ab42-ece44ff56e8c True label: passage Predicted label: phrase
# UUID: d27f9be5-87b6-42da-a576-992d1f8263b9 True label: phrase Predicted label: phrase
# UUID: 4ef6ef9e-a81d-4851-a218-9606f05ac123 True label: passage Predicted label: passage
# UUID: 21d60cef-ed8e-4b6d-a1ce-66f2fac0ccee True label: passage Predicted label: phrase
# UUID: a99716e1-5442-4995-9431-cfb1d432d00a True label: phrase Predicted label: passage
# UUID: 27c1ee45-fea0-48f0-b0f4-57e2ef38dadc True label: passage Predicted label: phrase
# UUID: 5ebe90f9-9a49-44d3-982b-c8b2433fc49d True label: passage Predicted label: passage
# UUID: bffcafdb-9244-4d30-8c9e-aebfb9b66743 True label: phrase Predicted label: phrase
# UUID: 0eb9d354-2286-4ba7-b8f5-1f3557936491 True label: phrase Predicted label: phrase
# UUID: 865539b0-2373-4a6b-b1ed-b24f559e6e79 True label: passage Predicted label: passage
# UUID: f2caf05d-e256-40ef-8aad-488a7daae18a True label: phrase Predicted label: phrase
# UUID: ba35ffbc-1eba-4940-8c68-00eefecd2178 True label: passage Predicted label: passage
# UUID: dc462cc9-5a22-442f-823e-eb1fb5d607c1 True label: phrase Predicted label: phrase
# UUID: ecd75fa9-4bef-4c4f-b269-39e91d8111d7 True label: phrase Predicted label: passage
# UUID: bdaa68de-e679-461d-a6b6-873a802a6e75 True label: multi Predicted label: phrase
# UUID: 9dd2ca6c-76e1-4a94-9b22-4a3a2fe2637f True label: multi Predicted label: multi
# UUID: d723c225-323a-49af-b11c-3aeb56116b14 True label: passage Predicted label: passage
# UUID: 3c8dc365-bb36-48c6-a0fd-cfe4bb99aec4 True label: phrase Predicted label: passage
# UUID: 307d08dc-2865-4bb5-af4f-6ee069e5908d True label: passage Predicted label: phrase
# UUID: 7d14a593-10bc-437f-a423-76647879508e True label: passage Predicted label: passage
# UUID: b0336437-885b-4d0a-90c1-8ca39c2d6da2 True label: phrase Predicted label: phrase
# UUID: 0b5c2fef-3f1a-4c09-8847-b90a30700acf True label: passage Predicted label: passage
# UUID: 47821ee7-3b73-4043-95df-b75703e496db True label: passage Predicted label: passage
# UUID: fa1050d8-ac8b-4127-8515-ef223af7c8e2 True label: passage Predicted label: phrase
# UUID: 93b96461-a7f7-4d4d-b862-a758f2af609d True label: phrase Predicted label: phrase
# UUID: 3d55bda2-40c4-447b-a806-87b14c665dde True label: phrase Predicted label: phrase
# UUID: 8bd60f06-a4cb-4694-91ed-e6c33cbc6183 True label: passage Predicted label: multi
# UUID: d278ec93-2c22-4e21-83fe-09a91d98716b True label: passage Predicted label: passage
# UUID: ff168dd8-edcb-45af-9be4-3980fd98cd4d True label: passage Predicted label: passage
# UUID: 7e33136e-a9ec-4389-904f-b10a0c298fee True label: phrase Predicted label: passage
# UUID: b8cb1614-a00f-4232-ab39-ccc75c6fdaa1 True label: phrase Predicted label: phrase
# UUID: 0131025e-17d5-4243-a820-d5438d974922 True label: passage Predicted label: passage
# UUID: 75c94509-1ad4-4057-b41d-04fff82676c2 True label: passage Predicted label: passage
# UUID: 338e3586-d3fd-4269-accb-0e2c745fd9b6 True label: phrase Predicted label: passage
# UUID: 69b92a67-f8e5-4cff-a84f-e6950fb23068 True label: phrase Predicted label: phrase
# UUID: 5fcfcd7e-7ce6-4139-a260-ae878ded2a4f True label: multi Predicted label: multi
# UUID: 6dc7ddef-4e8e-4a6b-9296-526377518071 True label: passage Predicted label: multi
# UUID: 81e13e23-9149-47c4-ad6c-d84e1f4f80a3 True label: multi Predicted label: phrase
# UUID: 2e5c865e-672b-43bd-adc3-76c7e5ef38db True label: passage Predicted label: multi
# UUID: cf17ad47-70f8-458f-8eb9-ef1f0b73fd0a True label: phrase Predicted label: phrase
# UUID: 033b9fbb-5930-4dae-afea-f8f6a3756004 True label: passage Predicted label: passage
# UUID: 0d360da8-a9d7-4f9d-b94a-172bbc396e1c True label: passage Predicted label: phrase
# UUID: 7b4758b2-db89-4584-bfa1-2fd42955a034 True label: phrase Predicted label: phrase
# UUID: 8ad8acc8-4728-46a4-a8bb-2eca0925e032 True label: multi Predicted label: multi
# UUID: fa6a24e8-b1a5-470c-93ff-799d5c8d008f True label: phrase Predicted label: phrase
# UUID: 4c14b253-d783-410e-847d-53bfbc5ed145 True label: phrase Predicted label: phrase
# UUID: b42515e6-0944-4172-8573-c6a0c0876a17 True label: passage Predicted label: passage
# UUID: 4052c15c-9e3e-4397-98c9-513b1f7d86d1 True label: passage Predicted label: passage
# UUID: 8200037b-a5f4-4cc4-a5c8-f66f6243cb17 True label: phrase Predicted label: phrase
# UUID: e3fa9074-960d-4b10-b7ff-97cff4a26682 True label: phrase Predicted label: passage
# UUID: 1af64fe8-881d-4bf8-b5f4-40d157ba8d1b True label: passage Predicted label: phrase
# UUID: 5c0185e9-494e-458f-a7d3-e9039948bb54 True label: phrase Predicted label: phrase
# UUID: f38a5363-0bd3-468a-b8dc-1298bc31e418 True label: phrase Predicted label: phrase
# UUID: ff0224e3-26e2-40f7-928e-dc0057e6ef94 True label: multi Predicted label: passage
# UUID: 8097f65a-be8b-4f3f-87d9-130ba34bc4a2 True label: passage Predicted label: passage
# UUID: 07133166-42e5-4342-afce-fe79121f5510 True label: phrase Predicted label: phrase
# UUID: 48776910-1a2f-4767-9380-45994535437b True label: passage Predicted label: passage
# UUID: 6c08cb61-8bc2-48af-8511-7feaa74fdf24 True label: phrase Predicted label: phrase
# UUID: 2ecfa7ff-e6cd-4c4f-9325-28d079e0d3fa True label: passage Predicted label: passage
# UUID: 9478034c-132b-4730-b0e4-4da42cdb8f2b True label: passage Predicted label: multi
# UUID: 40258287-e2f2-4491-81ca-fb8f40f6629a True label: passage Predicted label: passage
# UUID: 3a06b3a6-20bf-4162-9582-340eef2db9e5 True label: phrase Predicted label: passage
# UUID: a496c8b5-ba94-4b2f-b436-e8a0b085f275 True label: multi Predicted label: passage
# UUID: 1d701c07-2b18-4770-81ec-d54f7b566c3f True label: phrase Predicted label: phrase
# UUID: d7a0e8fc-d7ff-40e0-9c49-f4bacb9191b5 True label: passage Predicted label: passage
# UUID: 804ba7e2-2e3b-439b-9ee4-6827939c902d True label: phrase Predicted label: phrase
# UUID: fd6ba2e2-8395-430f-a044-190ad97f3d6c True label: passage Predicted label: passage
# UUID: 25a3e354-6dce-4be8-929f-0eefdfd4c222 True label: phrase Predicted label: passage
# UUID: 0cb1e413-f53d-4349-b82f-05d94b54d995 True label: phrase Predicted label: phrase
# UUID: 46dbc7d9-3cd6-40d0-929c-d1eefb4972a3 True label: multi Predicted label: passage
# UUID: 91a42135-f367-46d1-abb1-35296957e732 True label: passage Predicted label: passage
# UUID: 51a449e8-711f-471a-a156-35574ba2ec8c True label: phrase Predicted label: phrase
# UUID: f59ee683-26b4-4578-8227-7fdde7709d13 True label: phrase Predicted label: phrase
# UUID: 53760b50-1feb-46da-bb97-e469191fbf22 True label: passage Predicted label: passage
# UUID: b0fc2ff6-3634-4c40-aa2c-817b591d462b True label: phrase Predicted label: passage
# UUID: 7b75a305-11b0-44dd-92f3-267e6c87ff8e True label: phrase Predicted label: passage
# UUID: 79f4dd6e-0523-4eaa-a00f-994c867743b6 True label: multi Predicted label: phrase
# UUID: 3e4dbc10-049d-4e9b-9037-10f06fb56b2d True label: phrase Predicted label: passage
# UUID: 771ffe08-141c-41f4-b028-23a096dad6ec True label: passage Predicted label: phrase
# UUID: beb927d0-e318-4ad3-99df-d2ab6dc20df3 True label: phrase Predicted label: phrase
# UUID: 4878fe1a-a0ce-4a27-ba76-6f721e89c7dd True label: multi Predicted label: passage
# UUID: d844ef47-fae0-4f64-b48a-463a331c851f True label: phrase Predicted label: phrase
# UUID: 68b8e14d-ca9e-48f0-b57f-6e8c77c36c92 True label: phrase Predicted label: phrase
# UUID: 90a7328e-7b8f-4121-bd0c-375e246ce457 True label: phrase Predicted label: phrase
# UUID: 86956e97-7580-4a7e-9d0b-e9ca95f33d68 True label: passage Predicted label: passage
# UUID: dc808096-401b-4aba-b77c-70be4228d8db True label: multi Predicted label: passage
# UUID: 15e1f4bd-ff48-4177-97ba-d4855916edd8 True label: phrase Predicted label: phrase
# UUID: 4d7a12c9-c18c-4bb3-94f8-b16979260ee3 True label: passage Predicted label: phrase
# UUID: 6ea68956-e3cb-49fd-b7b4-f974ee78563d True label: multi Predicted label: phrase
# UUID: a89f0fce-936d-45ab-b1bd-3ef26268f7b2 True label: passage Predicted label: passage
# UUID: 37f1e60a-9afa-42de-bf1c-6669f03b0870 True label: passage Predicted label: multi
# UUID: dfa2ce74-cd26-41ce-9a40-facd2b54c6ef True label: multi Predicted label: multi
# UUID: d636e94d-d27a-4366-b177-1299c266d7b5 True label: phrase Predicted label: phrase
# UUID: 74d75507-1194-4141-9259-4a9e875a124b True label: multi Predicted label: multi
# UUID: 276eaf39-bb91-44b6-8354-782f731f676d True label: phrase Predicted label: passage
# UUID: 34a99393-ceb7-4e0a-9ca1-a9829f7edc8d True label: phrase Predicted label: phrase
# UUID: 2dbccb80-3bfc-4a2a-80f2-a24511b70213 True label: phrase Predicted label: multi
# UUID: 43a957c5-5b94-41de-a969-1b3c9cbf076c True label: phrase Predicted label: phrase
# UUID: 7fea0bc5-481b-4808-ac23-0ce9e010ede3 True label: passage Predicted label: passage
# UUID: 55649933-a7be-498e-ab6a-610df1148cc8 True label: multi Predicted label: passage
# UUID: 742db6d2-2037-41ca-9cb9-39898efa0437 True label: passage Predicted label: passage
# UUID: b30bec9e-6be4-4dbf-9e76-aeafb6a36ce3 True label: phrase Predicted label: passage
# UUID: 1481c5c8-d3cf-4ff1-aaab-0cdad1d7fe82 True label: passage Predicted label: passage
# UUID: 088b3f0a-4001-4bdf-9155-be9728d8a65d True label: phrase Predicted label: passage
# UUID: 99d3c2f5-47e3-42ae-90ee-c65c153e011b True label: passage Predicted label: passage
# UUID: 0b850ec1-1cf9-49d9-96bf-e33311d19bf8 True label: phrase Predicted label: phrase
# UUID: cbab5c34-334d-444b-b89f-1c3b4448a66f True label: multi Predicted label: passage
# UUID: 34e0d648-6168-4ac9-9ac6-3064c6a01573 True label: phrase Predicted label: phrase
# UUID: 682755b7-de64-443b-9570-980750a65421 True label: phrase Predicted label: phrase
# UUID: 0b0d15ae-6282-4c4c-931e-6165143413fc True label: passage Predicted label: phrase
# UUID: 86e99d01-7785-4065-8ad2-e44305b89ffa True label: passage Predicted label: phrase
# UUID: d3c737e1-1680-4aab-b3cd-d5006f817f0b True label: phrase Predicted label: passage
# UUID: 82504668-b729-442f-aa29-ec1662373470 True label: phrase Predicted label: phrase
# UUID: d86acd6f-b007-430b-9264-90793967b1d5 True label: phrase Predicted label: phrase
# UUID: 7f99433b-0a2d-449c-9d19-720c0cc74fc1 True label: passage Predicted label: passage
# UUID: 8712f91c-8faa-44f1-a886-93fb0bacf1cb True label: phrase Predicted label: phrase
# UUID: 34de51fb-cd0e-4260-ad3e-3e32dc679e44 True label: phrase Predicted label: phrase
# UUID: 97788966-1046-4677-b2bc-b966be7d9aa2 True label: passage Predicted label: phrase
# UUID: f0bd9abe-700d-422c-b238-be108d97626b True label: phrase Predicted label: phrase
# UUID: 28955cc8-c6d8-4f58-b026-e77e7a0924cf True label: passage Predicted label: passage
# UUID: 68a7eb69-a70a-4b6f-8d73-0dd2d8da65fa True label: multi Predicted label: phrase
# UUID: 3a44b6f4-dfb2-4f1b-8f67-ceebfc9b065a True label: multi Predicted label: passage
# UUID: cca0fcd7-083e-462c-9a86-72c8343f9401 True label: passage Predicted label: passage
# UUID: 7b7f1ba4-6c3e-4a8c-b0e8-7636030eafed True label: phrase Predicted label: passage
# UUID: 82a6cbf1-b003-4658-9d22-036f5635a8e7 True label: passage Predicted label: passage
# UUID: f9f23cfc-7bf5-4ad1-b0c8-2fb1e4f5a7dc True label: passage Predicted label: phrase
# UUID: f2d774b4-3a17-4055-b8b9-106add0f30d0 True label: multi Predicted label: phrase
# UUID: b0dd5df0-514a-40c3-bbbd-993a3cc0efbe True label: passage Predicted label: passage
# UUID: d5399116-ce4d-4038-9960-ef299dca383b True label: phrase Predicted label: passage
# UUID: eaa28a46-4453-4a0c-a857-237fa46ef756 True label: passage Predicted label: passage
# UUID: b3f5563b-132d-48cf-96db-ac67ae8a0538 True label: phrase Predicted label: passage
# UUID: bf3b4d30-4ffc-469f-b69e-63ecde6ec3de True label: passage Predicted label: phrase
# UUID: bada7224-5835-4b3d-8737-d57450b93dea True label: phrase Predicted label: passage
# UUID: 3609d700-2307-4dc9-8a51-a30b625eddea True label: phrase Predicted label: phrase
# UUID: 13019e4a-00ec-4c9b-9d2c-e3c023df2edd True label: passage Predicted label: passage
# Accuracy: 0.644
# Precision: 0.587
# Recall: 0.560
# F1-score: 0.568

# %% [markdown]
# ## Predicting

# %%
tokenizer = AutoTokenizer.from_pretrained(
    f"/content/drive/My Drive/Colab Notebooks/2023-ILTAPP/APP1_Assignment/models/{configuration}{model_name}/checkpoint-2000")
model = AutoModelForSequenceClassification.from_pretrained(
    f"/content/drive/My Drive/Colab Notebooks/2023-ILTAPP/APP1_Assignment/models/{configuration}{model_name}/checkpoint-2000")

dataset_to_pred = [
    {"uuid": "24545-445654-78786", "text": "Text to try if this works correctly"},
    {"uuid": "46768-448646-46456", "text": "She went to the beach in February"},
    {"uuid": "79785-113215-49989", "text": "This is the input text for example 246845"}
]

example_dataset = Dataset.from_pandas(pd.DataFrame(dataset_to_pred))

for example in example_dataset:
    inputs = tokenizer(example['text'], return_tensors="pt", max_length=512, truncation=True)
    with torch.no_grad():
        logits = model(**inputs).logits
    predicted_class_id = logits.argmax().item()
    predicted_label = model.config.id2label[predicted_class_id]
    print(f"uuid: {example['uuid']}, spoilerType: {predicted_label}")
# Out:
# uuid: 24545-445654-78786, spoilerType: passage
# uuid: 46768-448646-46456, spoilerType: phrase
# uuid: 79785-113215-49989, spoilerType: passage
